# %% [markdown]
# <a href="https://colab.research.google.com/github/PacktPublishing/Hands-On-Computer-Vision-with-PyTorch/blob/master/Chapter09/Semantic_Segmentation_with_U_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Modified from Modern Computer Vision with PyTorch

# %%
import os
from torch_snippets import *
from torchvision import transforms
from sklearn.model_selection import train_test_split
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ### Define the Dataset class and create the data loaders

# %%
tfms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # imagenet
])

# %%
class SegData(Dataset):
    def __init__(self, split):
        self.items = stems(f'./images/semantic-segm/images_prepped_{split}')
        self.split = split
    def __len__(self):
        return len(self.items)
    def __getitem__(self, ix):
        image = read(f'./images/semantic-segm/images_prepped_{self.split}/{self.items[ix]}.png', 1)
        image = cv2.resize(image, (224,224))
        mask = read(f'./images/semantic-segm/annotations_prepped_{self.split}/{self.items[ix]}.png')
        mask = cv2.resize(mask, (224,224))
        return image, mask
    def choose(self): return self[randint(len(self))]
    def collate_fn(self, batch):
        ims, masks = list(zip(*batch))
        ims = torch.cat([tfms(im.copy()/255.)[None] for im in ims]).float().to(device)
        ce_masks = torch.cat([torch.Tensor(mask[None]) for mask in masks]).long().to(device)
        return ims, ce_masks

# %%
trn_ds = SegData('train')
val_ds = SegData('test')
trn_dl = DataLoader(trn_ds, batch_size=4, shuffle=True, collate_fn=trn_ds.collate_fn)
val_dl = DataLoader(val_ds, batch_size=1, shuffle=True, collate_fn=val_ds.collate_fn)

# %%
show(trn_ds[10][0])
print(trn_ds[10][0].shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# ### Define the model using VGG16 for the encoder

# %%
def conv(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True)
    )

# %%
def up_conv(in_channels, out_channels):
    return nn.Sequential(
        nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2),
        nn.ReLU(inplace=True)
    )

# %%
from torchvision.models import vgg16_bn
class UNet(nn.Module):
    def __init__(self, out_channels=12):
        super().__init__()

        self.encoder = vgg16_bn(weights='IMAGENET1K_V1').features
        self.block1 = nn.Sequential(*self.encoder[:6]) 
        self.block2 = nn.Sequential(*self.encoder[6:13])
        self.block3 = nn.Sequential(*self.encoder[13:20])
        self.block4 = nn.Sequential(*self.encoder[20:27])
        self.block5 = nn.Sequential(*self.encoder[27:34])

        self.bottleneck = nn.Sequential(*self.encoder[34:])
        self.conv_bottleneck = conv(512, 1024)

        self.up_conv6 = up_conv(1024, 512)
        self.conv6 = conv(512 + 512, 512)
        self.up_conv7 = up_conv(512, 256)
        self.conv7 = conv(256 + 512, 256)
        self.up_conv8 = up_conv(256, 128)
        self.conv8 = conv(128 + 256, 128)
        self.up_conv9 = up_conv(128, 64)
        self.conv9 = conv(64 + 128, 64)
        self.up_conv10 = up_conv(64, 32)
        self.conv10 = conv(32 + 64, 32)
        self.conv11 = nn.Conv2d(32, out_channels, kernel_size=1)
    def forward(self, x):
        block1 = self.block1(x)              # image size of the output is 64 x 224 x 224  
        block2 = self.block2(block1)         # image size of the output is 128 x 112 x 112
        block3 = self.block3(block2)         # image size of the output is 256 x 56 x 56
        block4 = self.block4(block3)         # image size of the output is 512 x 28 x 28
        block5 = self.block5(block4)         # image size of the output is 512 x 14 x 14

        bottleneck = self.bottleneck(block5) # image size of the output is 512 x 7 x 7
        x = self.conv_bottleneck(bottleneck) # image size of the output is 1024 x 7 x 7
        
        x = self.up_conv6(x)                 # image size of the output is 512 x 14 x 14          
        x = torch.cat([x, block5], dim=1)    # image size of the output is 1024 x 14 x 14 
        x = self.conv6(x)                    # image size of the output is 512 x 14 x 14 
    
        x = self.up_conv7(x)                 # image size of the output is 256 x 28 x 28
        x = torch.cat([x, block4], dim=1)    # image size of the output is 768 x 28 x 28 
        x = self.conv7(x)                    # image size of the output is 256 x 28 x 28
    
        
        x = self.up_conv8(x)                 # image size of the output is 128 x 56 x 56
        x = torch.cat([x, block3], dim=1)    # image size of the output is 384 x 28 x 28
        x = self.conv8(x)                    # image size of the output is 128 x 56 x 56 
        
        x = self.up_conv9(x)                 # image size of the output is 64 x 112 x 112
        x = torch.cat([x, block2], dim=1)    # image size of the output is 192 x 112 x 112
        x = self.conv9(x)                    # image size of the output is 64 x 112 x 112
        
        x = self.up_conv10(x)                # image size of the output is 32 x 224 x 224
        x = torch.cat([x, block1], dim=1)    # image size of the output is 96 x 224 x 224
        x = self.conv10(x)                   # image size of the output is 32 x 224 x 224

        x = self.conv11(x)                   # image size of the output is 12 classes x 224 x 224

        return x

# %% [markdown]
# ### Define the loss function

# %%
ce = nn.CrossEntropyLoss()
def UnetLoss(preds, targets):
    ce_loss = ce(preds, targets)
    acc = (torch.max(preds, 1)[1] == targets).float().mean()
    return ce_loss, acc

# %% [markdown]
# ### Define the training and validation functions

# %%
def train_batch(model, data, optimizer, criterion):
    model.train()
    ims, ce_masks = data
    _masks = model(ims)
    optimizer.zero_grad()
    loss, acc = criterion(_masks, ce_masks)
    loss.backward()
    optimizer.step()
    return loss.item(), acc.item()

@torch.no_grad()
def validate_batch(model, data, criterion):
    model.eval()
    ims, masks = data
    _masks = model(ims)
    loss, acc = criterion(_masks, masks)
    return loss.item(), acc.item()

# %% [markdown]
# ### Create the model and define its hiperparameters

# %%
model = UNet().to(device)
criterion = UnetLoss
optimizer = optim.Adam(model.parameters(), lr=1e-3)
n_epochs  = 20
from torchsummary import summary
summary(model, (3,224,224))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /home/afalcao/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-1                       [-1, 64, 224, 224]        1,792
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-2                       [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-3                  [-1, 64, 224, 224]        128
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-4                  [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-5                         [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-6                         [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-7                       [-1, 64, 224, 224]        36,928
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-8                       [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-9                  [-1, 64, 224, 224]        128
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-10                 [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-11                        [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-12                        [-1, 64, 224, 224]        --
# ├─Sequential: 1-2                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-13                   [-1, 64, 112, 112]        --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-14                   [-1, 64, 112, 112]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-15                      [-1, 128, 112, 112]       73,856
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-16                      [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-17                 [-1, 128, 112, 112]       256
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-18                 [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-19                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-20                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-21                      [-1, 128, 112, 112]       147,584
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-22                      [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-23                 [-1, 128, 112, 112]       256
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-24                 [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-25                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-26                        [-1, 128, 112, 112]       --
# ├─Sequential: 1-3                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-27                   [-1, 128, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-28                   [-1, 128, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-29                      [-1, 256, 56, 56]         295,168
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-30                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-31                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-32                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-33                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-34                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-35                      [-1, 256, 56, 56]         590,080
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-36                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-37                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-38                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-39                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-40                        [-1, 256, 56, 56]         --
# ├─Sequential: 1-4                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-41                      [-1, 256, 56, 56]         590,080
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-42                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-43                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-44                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-45                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-46                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-47                   [-1, 256, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-48                   [-1, 256, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-49                      [-1, 512, 28, 28]         1,180,160
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-50                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-51                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-52                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-53                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-54                        [-1, 512, 28, 28]         --
# ├─Sequential: 1-5                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-55                      [-1, 512, 28, 28]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-56                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-57                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-58                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-59                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-60                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-61                      [-1, 512, 28, 28]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-62                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-63                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-64                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-65                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-66                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-67                   [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-68                   [-1, 512, 14, 14]         --
# ├─Sequential: 1-6                        [-1, 512, 7, 7]           --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-69                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-70                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-71                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-72                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-73                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-74                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-75                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-76                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-77                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-78                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-79                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-80                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-81                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-82                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-83                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-84                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-85                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-86                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-87                   [-1, 512, 7, 7]           --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-88                   [-1, 512, 7, 7]           --
# ├─Sequential: 1-7                        [-1, 1024, 7, 7]          --
# |    └─Conv2d: 2-89                      [-1, 1024, 7, 7]          4,719,616
# |    └─BatchNorm2d: 2-90                 [-1, 1024, 7, 7]          2,048
# |    └─ReLU: 2-91                        [-1, 1024, 7, 7]          --
# ├─Sequential: 1-8                        [-1, 512, 14, 14]         --
# |    └─ConvTranspose2d: 2-92             [-1, 512, 14, 14]         2,097,664
# |    └─ReLU: 2-93                        [-1, 512, 14, 14]         --
# ├─Sequential: 1-9                        [-1, 512, 14, 14]         --
# |    └─Conv2d: 2-94                      [-1, 512, 14, 14]         4,719,104
# |    └─BatchNorm2d: 2-95                 [-1, 512, 14, 14]         1,024
# |    └─ReLU: 2-96                        [-1, 512, 14, 14]         --
# ├─Sequential: 1-10                       [-1, 256, 28, 28]         --
# |    └─ConvTranspose2d: 2-97             [-1, 256, 28, 28]         524,544
# |    └─ReLU: 2-98                        [-1, 256, 28, 28]         --
# ├─Sequential: 1-11                       [-1, 256, 28, 28]         --
# |    └─Conv2d: 2-99                      [-1, 256, 28, 28]         1,769,728
# |    └─BatchNorm2d: 2-100                [-1, 256, 28, 28]         512
# |    └─ReLU: 2-101                       [-1, 256, 28, 28]         --
# ├─Sequential: 1-12                       [-1, 128, 56, 56]         --
# |    └─ConvTranspose2d: 2-102            [-1, 128, 56, 56]         131,200
# |    └─ReLU: 2-103                       [-1, 128, 56, 56]         --
# ├─Sequential: 1-13                       [-1, 128, 56, 56]         --
# |    └─Conv2d: 2-104                     [-1, 128, 56, 56]         442,496
# |    └─BatchNorm2d: 2-105                [-1, 128, 56, 56]         256
# |    └─ReLU: 2-106                       [-1, 128, 56, 56]         --
# ├─Sequential: 1-14                       [-1, 64, 112, 112]        --
# |    └─ConvTranspose2d: 2-107            [-1, 64, 112, 112]        32,832
# |    └─ReLU: 2-108                       [-1, 64, 112, 112]        --
# ├─Sequential: 1-15                       [-1, 64, 112, 112]        --
# |    └─Conv2d: 2-109                     [-1, 64, 112, 112]        110,656
# |    └─BatchNorm2d: 2-110                [-1, 64, 112, 112]        128
# |    └─ReLU: 2-111                       [-1, 64, 112, 112]        --
# ├─Sequential: 1-16                       [-1, 32, 224, 224]        --
# |    └─ConvTranspose2d: 2-112            [-1, 32, 224, 224]        8,224
# |    └─ReLU: 2-113                       [-1, 32, 224, 224]        --
# ├─Sequential: 1-17                       [-1, 32, 224, 224]        --
# |    └─Conv2d: 2-114                     [-1, 32, 224, 224]        27,680
# |    └─BatchNorm2d: 2-115                [-1, 32, 224, 224]        64
# |    └─ReLU: 2-116                       [-1, 32, 224, 224]        --
# ├─Conv2d: 1-18                           [-1, 12, 224, 224]        396
# ==========================================================================================
# Total params: 29,311,308
# Trainable params: 29,311,308
# Non-trainable params: 0
# Total mult-adds (G): 39.50
# ==========================================================================================
# Input size (MB): 0.57
# Forward/backward pass size (MB): 283.28
# Params size (MB): 111.81
# Estimated Total Size (MB): 395.67
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-1                       [-1, 64, 224, 224]        1,792
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-2                       [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-3                  [-1, 64, 224, 224]        128
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-4                  [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-5                         [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-6                         [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-7                       [-1, 64, 224, 224]        36,928
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-8                       [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-9                  [-1, 64, 224, 224]        128
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-10                 [-1, 64, 224, 224]        (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-11                        [-1, 64, 224, 224]        --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-12                        [-1, 64, 224, 224]        --
# ├─Sequential: 1-2                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-13                   [-1, 64, 112, 112]        --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-14                   [-1, 64, 112, 112]        --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-15                      [-1, 128, 112, 112]       73,856
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-16                      [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-17                 [-1, 128, 112, 112]       256
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-18                 [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-19                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-20                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-21                      [-1, 128, 112, 112]       147,584
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-22                      [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-23                 [-1, 128, 112, 112]       256
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-24                 [-1, 128, 112, 112]       (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-25                        [-1, 128, 112, 112]       --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-26                        [-1, 128, 112, 112]       --
# ├─Sequential: 1-3                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-27                   [-1, 128, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-28                   [-1, 128, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-29                      [-1, 256, 56, 56]         295,168
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-30                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-31                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-32                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-33                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-34                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-35                      [-1, 256, 56, 56]         590,080
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-36                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-37                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-38                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-39                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-40                        [-1, 256, 56, 56]         --
# ├─Sequential: 1-4                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-41                      [-1, 256, 56, 56]         590,080
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-42                      [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-43                 [-1, 256, 56, 56]         512
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-44                 [-1, 256, 56, 56]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-45                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-46                        [-1, 256, 56, 56]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-47                   [-1, 256, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-48                   [-1, 256, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-49                      [-1, 512, 28, 28]         1,180,160
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-50                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-51                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-52                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-53                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-54                        [-1, 512, 28, 28]         --
# ├─Sequential: 1-5                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-55                      [-1, 512, 28, 28]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-56                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-57                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-58                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-59                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-60                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-61                      [-1, 512, 28, 28]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-62                      [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-63                 [-1, 512, 28, 28]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-64                 [-1, 512, 28, 28]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-65                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-66                        [-1, 512, 28, 28]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-67                   [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-68                   [-1, 512, 14, 14]         --
# ├─Sequential: 1-6                        [-1, 512, 7, 7]           --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-69                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-70                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-71                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-72                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-73                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-74                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-75                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-76                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-77                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-78                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-79                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-80                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-81                      [-1, 512, 14, 14]         2,359,808
# ├─Sequential: 1                          []                        --
# |    └─Conv2d: 2-82                      [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-83                 [-1, 512, 14, 14]         1,024
# ├─Sequential: 1                          []                        --
# |    └─BatchNorm2d: 2-84                 [-1, 512, 14, 14]         (recursive)
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-85                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─ReLU: 2-86                        [-1, 512, 14, 14]         --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-87                   [-1, 512, 7, 7]           --
# ├─Sequential: 1                          []                        --
# |    └─MaxPool2d: 2-88                   [-1, 512, 7, 7]           --
# ├─Sequential: 1-7                        [-1, 1024, 7, 7]          --
# |    └─Conv2d: 2-89                      [-1, 1024, 7, 7]          4,719,616
# |    └─BatchNorm2d: 2-90                 [-1, 1024, 7, 7]          2,048
# |    └─ReLU: 2-91                        [-1, 1024, 7, 7]          --
# ├─Sequential: 1-8                        [-1, 512, 14, 14]         --
# |    └─ConvTranspose2d: 2-92             [-1, 512, 14, 14]         2,097,664
# |    └─ReLU: 2-93                        [-1, 512, 14, 14]         --
# ├─Sequential: 1-9                        [-1, 512, 14, 14]         --
# |    └─Conv2d: 2-94                      [-1, 512, 14, 14]         4,719,104
# |    └─BatchNorm2d: 2-95                 [-1, 512, 14, 14]         1,024
# |    └─ReLU: 2-96                        [-1, 512, 14, 14]         --
# ├─Sequential: 1-10                       [-1, 256, 28, 28]         --
# |    └─ConvTranspose2d: 2-97             [-1, 256, 28, 28]         524,544
# |    └─ReLU: 2-98                        [-1, 256, 28, 28]         --
# ├─Sequential: 1-11                       [-1, 256, 28, 28]         --
# |    └─Conv2d: 2-99                      [-1, 256, 28, 28]         1,769,728
# |    └─BatchNorm2d: 2-100                [-1, 256, 28, 28]         512
# |    └─ReLU: 2-101                       [-1, 256, 28, 28]         --
# ├─Sequential: 1-12                       [-1, 128, 56, 56]         --
# |    └─ConvTranspose2d: 2-102            [-1, 128, 56, 56]         131,200
# |    └─ReLU: 2-103                       [-1, 128, 56, 56]         --
# ├─Sequential: 1-13                       [-1, 128, 56, 56]         --
# |    └─Conv2d: 2-104                     [-1, 128, 56, 56]         442,496
# |    └─BatchNorm2d: 2-105                [-1, 128, 56, 56]         256
# |    └─ReLU: 2-106                       [-1, 128, 56, 56]         --
# ├─Sequential: 1-14                       [-1, 64, 112, 112]        --
# |    └─ConvTranspose2d: 2-107            [-1, 64, 112, 112]        32,832
# |    └─ReLU: 2-108                       [-1, 64, 112, 112]        --
# ├─Sequential: 1-15                       [-1, 64, 112, 112]        --
# |    └─Conv2d: 2-109                     [-1, 64, 112, 112]        110,656
# |    └─BatchNorm2d: 2-110                [-1, 64, 112, 112]        128
# |    └─ReLU: 2-111                       [-1, 64, 112, 112]        --
# ├─Sequential: 1-16                       [-1, 32, 224, 224]        --
# |    └─ConvTranspose2d: 2-112            [-1, 32, 224, 224]        8,224
# |    └─ReLU: 2-113                       [-1, 32, 224, 224]        --
# ├─Sequential: 1-17                       [-1, 32, 224, 224]        --
# |    └─Conv2d: 2-114                     [-1, 32, 224, 224]        27,680
# |    └─BatchNorm2d: 2-115                [-1, 32, 224, 224]        64
# |    └─ReLU: 2-116                       [-1, 32, 224, 224]        --
# ├─Conv2d: 1-18                           [-1, 12, 224, 224]        396
# ==========================================================================================
# Total params: 29,311,308
# Trainable params: 29,311,308
# Non-trainable params: 0
# Total mult-adds (G): 39.50
# ==========================================================================================
# Input size (MB): 0.57
# Forward/backward pass size (MB): 283.28
# Params size (MB): 111.81
# Estimated Total Size (MB): 395.67
# ==========================================================================================

# %% [markdown]
# ### Train and evaluate the model

# %%
log = Report(n_epochs)
for ex in range(n_epochs):
    N = len(trn_dl)
    for bx, data in enumerate(trn_dl):
        loss, acc = train_batch(model, data, optimizer, criterion)
        log.record(ex+(bx+1)/N, trn_loss=loss, trn_acc=acc, end='\r')

    N = len(val_dl)
    for bx, data in enumerate(val_dl):
        loss, acc = validate_batch(model, data, criterion)
        log.record(ex+(bx+1)/N, val_loss=loss, val_acc=acc, end='\r')
        
    if (ex+1) % 10: log.report_avgs(ex+1)
# Out:
# EPOCH: 1.000	trn_loss: 1.225	trn_acc: 0.710	val_loss: 0.978	val_acc: 0.732	(14.78s - 280.74s remaining)
# EPOCH: 2.000	trn_loss: 0.705	trn_acc: 0.824	val_loss: 0.647	val_acc: 0.844	(23.33s - 209.93s remaining)
# EPOCH: 3.000	trn_loss: 0.590	trn_acc: 0.842	val_loss: 0.555	val_acc: 0.862	(31.89s - 180.73s remaining)
# EPOCH: 4.000	trn_loss: 0.512	trn_acc: 0.861	val_loss: 0.501	val_acc: 0.869	(40.44s - 161.76s remaining)
# EPOCH: 5.000	trn_loss: 0.482	trn_acc: 0.865	val_loss: 0.523	val_acc: 0.845	(48.95s - 146.84s remaining)
# EPOCH: 6.000	trn_loss: 0.438	trn_acc: 0.878	val_loss: 0.700	val_acc: 0.811	(57.48s - 134.12s remaining)
# EPOCH: 7.000	trn_loss: 0.409	trn_acc: 0.884	val_loss: 0.476	val_acc: 0.854	(66.00s - 122.58s remaining)
# EPOCH: 8.000	trn_loss: 0.375	trn_acc: 0.894	val_loss: 0.433	val_acc: 0.870	(74.54s - 111.81s remaining)
# EPOCH: 9.000	trn_loss: 0.358	trn_acc: 0.899	val_loss: 0.459	val_acc: 0.866	(83.06s - 101.52s remaining)
# EPOCH: 11.000	trn_loss: 0.324	trn_acc: 0.908	val_loss: 0.422	val_acc: 0.876	(100.11s - 81.91s remaining)
# EPOCH: 12.000	trn_loss: 0.311	trn_acc: 0.912	val_loss: 0.544	val_acc: 0.846	(108.63s - 72.42s remaining)
# EPOCH: 13.000	trn_loss: 0.299	trn_acc: 0.915	val_loss: 0.361	val_acc: 0.894	(117.17s - 63.09s remaining)
# EPOCH: 14.000	trn_loss: 0.274	trn_acc: 0.923	val_loss: 0.389	val_acc: 0.884	(125.69s - 53.87s remaining)
# EPOCH: 15.000	trn_loss: 0.268	trn_acc: 0.924	val_loss: 0.420	val_acc: 0.877	(134.24s - 44.75s remaining)
# EPOCH: 16.000	trn_loss: 0.260	trn_acc: 0.926	val_loss: 0.394	val_acc: 0.886	(142.79s - 35.70s remaining)
# EPOCH: 17.000	trn_loss: 0.248	trn_acc: 0.930	val_loss: 0.390	val_acc: 0.892	(151.33s - 26.71s remaining)
# EPOCH: 18.000	trn_loss: 0.241	trn_acc: 0.931	val_loss: 0.367	val_acc: 0.902	(159.90s - 17.77s remaining)
# EPOCH: 19.000	trn_loss: 0.225	trn_acc: 0.936	val_loss: 0.391	val_acc: 0.895	(168.42s - 8.86s remaining)
# EPOCH: 20.000	val_loss: 0.388	val_acc: 0.895	(177.02s - 0.00s remaining)

# %% [markdown]
# ### Report the results

# %%
log.plot_epochs(['trn_loss','val_loss'])
log.plot_epochs(['trn_acc','val_acc'])
# Out:
# 100%|███████████████████████████████████████| 121/121 [00:00<00:00, 1392.34it/s]
# 100%|███████████████████████████████████████| 121/121 [00:00<00:00, 2265.82it/s]

# %% [markdown]
# ### Deploy the model in images of the validation set

# %%
im, mask = next(iter(val_dl))
_mask = model(im)
_, _mask = torch.max(_mask, dim=1)
subplots([im[0].permute(1,2,0).detach().cpu()[:,:,0], mask.permute(1,2,0).detach().cpu()[:,:,0]
,_mask.permute(1,2,0).detach().cpu()[:,:,0]],
nc=3, titles=['Original image','Original mask','Predicted mask'])
